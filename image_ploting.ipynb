# %% [markdown]
# <a href="https://colab.research.google.com/github/21075A6603/image_processing/blob/main/image_ploting.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import skimage
import numpy as np
from PIL import Image
import matplotlib.pylab as pylab
from skimage import data,img_as_float,img_as_ubyte,exposure,io,color
import matplotlib.pylab as plt
from skimage.color import rgb2gray
from skimage.io import imread

# %%
im1=Image.open("/content/connat2.jpg")

# %%
pylab.imshow(im1)

# %%
print(im1.format)
# Out:
# JPEG

# %%
print(im1.mode)
# Out:
# RGB

# %%
print(im1.width)
# Out:
# 275

# %%
print(im1.height)
# Out:
# 183

# %%
print(type(im1))
# Out:
# <class 'PIL.JpegImagePlugin.JpegImageFile'>

# %%
import cv2

# read the input image
img = cv2.imread('/content/gray2.jpg')

# %%
# access pixel values using indexing
print("pixel value at [200,150]:", img[200,150])
print("pixel value blue channel at [200,150]:", img[200,150][0])
print("pixel value green channel at [200,150]:", img[200,150][1])
print("pixel value red channel at[200,150]:", img[200,150][2])

# modify the pixel value at [200,150] for red color channel
img[200,150] = (0, 0, 255)
print("after modifying pixel value at [200,150]:", img[200,150])
# Out:
# pixel value at [200,150]: [196 196 196]
# pixel value blue channel at [200,150]: 196
# pixel value green channel at [200,150]: 196
# pixel value red channel at[200,150]: 196
# after modifying pixel value at [200,150]: [  0   0 255]

# %%
img.shape
# Out:
# (300, 332, 3)

# %%
img[200]

# %%
img[0][0]
# Out:
# array([89, 89, 89], dtype=uint8)

# %%
img[1][0]
# Out:
# array([89, 89, 89], dtype=uint8)

# %%
img = cv2.imread('/content/gray2.jpg',0)
plt.hist(img.ravel(),256,[0,256]); plt.show()
pylab.imshow(img)

# %%
img = cv2.imread('/content/cont1.jpg',0)
plt.hist(img.ravel(),256,[0,256]); plt.show()
pylab.imshow(img)

# %%
img = cv2.imread('/content/gray1.jpg',0)
plt.hist(img.ravel(),256,[0,256]); plt.show()
pylab.imshow(img)

# %%
img = cv2.imread('/content/gray3.jpg',0)
plt.hist(img.ravel(),256,[0,256]); plt.show()
pylab.imshow(img)

# %%
im1=Image.open("/content/gray1.jpg")
print(im1.mode)
# Out:
# RGB

# %%
# !pip install git
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ERROR: Could not find a version that satisfies the requirement git (from versions: none)
# ERROR: No matching distribution found for git

# %%
 git add image_plotting.ipynb
# Out:
#   File "<ipython-input-36-8162f78dadfb>", line 1
#     git add image_plotting.ipynb
#         ^
# SyntaxError: invalid syntax
