# %% [markdown]
# <a href="https://colab.research.google.com/github/21075A6603/image_processing/blob/main/median_filter.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2

# %%
img=cv2.imread('/content/noise.jpeg')
# from google.colab.patches import cv2_imshow
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=600x399>

# %%
median_filter=cv2.medianBlur(img,5)

# %%
from google.colab.patches import cv2_imshow

# %%
cv2_imshow(median_filter)
# Out:
# <PIL.Image.Image image mode=RGB size=600x399>

# %%
median_filter1=cv2.medianBlur(median_filter,5)
cv2_imshow(median_filter1)
# Out:
# <PIL.Image.Image image mode=RGB size=600x399>

# %%
median_filter2=cv2.medianBlur(median_filter1,5)
cv2_imshow(median_filter2)
# Out:
# <PIL.Image.Image image mode=RGB size=600x399>

# %%
median_filter3=cv2.medianBlur(median_filter2,5)
cv2_imshow(median_filter3)
# Out:
# <PIL.Image.Image image mode=RGB size=600x399>

# %%
median_filter4=cv2.medianBlur(median_filter3,5)
cv2_imshow(median_filter4)
# Out:
# <PIL.Image.Image image mode=RGB size=600x399>

# %%
median_filter5=cv2.medianBlur(median_filter4,5)
cv2_imshow(median_filter5)
# Out:
# <PIL.Image.Image image mode=RGB size=600x399>
